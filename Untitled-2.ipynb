# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("epldata_final.csv")
df
# Out:
#                         name         club  age position  position_cat  \
# 0             Alexis Sanchez      Arsenal   28       LW             1
# 1                 Mesut Ozil      Arsenal   28       AM             1
# 2                  Petr Cech      Arsenal   35       GK             4
# 3               Theo Walcott      Arsenal   28       RW             1
# 4          Laurent Koscielny      Arsenal   31       CB             3
# 5            Hector Bellerin      Arsenal   22       RB             3
# 6             Olivier Giroud      Arsenal   30       CF             1
# 7              Nacho Monreal      Arsenal   31       LB             3
# 8           Shkodran Mustafi      Arsenal   25       CB             3
# 9                 Alex Iwobi      Arsenal   21       LW             1
# 10              Granit Xhaka      Arsenal   24       DM             2
# 11   Alex Oxlade-Chamberlain      Arsenal   23       RM             2
# ...

# %%
# Extracting the name columns and market_value and read it
valuable_players=df[["name","market_value","fpl_value"]]
valuable_players
# Out:
#                         name  market_value  fpl_value
# 0             Alexis Sanchez         65.00       12.0
# 1                 Mesut Ozil         50.00        9.5
# 2                  Petr Cech          7.00        5.5
# 3               Theo Walcott         20.00        7.5
# 4          Laurent Koscielny         22.00        6.0
# 5            Hector Bellerin         30.00        6.0
# 6             Olivier Giroud         22.00        8.5
# 7              Nacho Monreal         13.00        5.5
# 8           Shkodran Mustafi         30.00        5.5
# 9                 Alex Iwobi         10.00        5.5
# 10              Granit Xhaka         35.00        5.5
# 11   Alex Oxlade-Chamberlain         22.00        6.0
# 12             Jack Wilshere         18.00        5.5
# 13              Aaron Ramsey         35.00        7.0
# 14          Francis Coquelin         15.00        4.5
# 15          Gabriel Paulista         13.00        5.0
# ...

# %%
valuable_players=valuable_players.sort_values('market_value',ascending=False)

# %%
valuable_players.head()
# Out:
#                 name  market_value  fpl_value
# 92       Eden Hazard          75.0       10.5
# 263       Paul Pogba          75.0        8.0
# 0     Alexis Sanchez          65.0       12.0
# 240  Kevin De Bruyne          65.0       10.0
# 241    Sergio Aguero          65.0       11.5

# %%
# calculate the corralation between market_value and fpl_value
corr_value=df['market_value'].corr(df['fpl_value'])
corr_value
# Out:
# 0.7886534125526211

# %%
# Extract the fpl_sel to see who is the ost popular player
popular_player=df[['name','fpl_sel','page_views']]
popular_player
# Out:
#                         name fpl_sel  page_views
# 0             Alexis Sanchez  17.10%        4329
# 1                 Mesut Ozil   5.60%        4395
# 2                  Petr Cech   5.90%        1529
# 3               Theo Walcott   1.50%        2393
# 4          Laurent Koscielny   0.70%         912
# 5            Hector Bellerin  13.70%        1675
# 6             Olivier Giroud   2.50%        2230
# 7              Nacho Monreal   4.70%         555
# 8           Shkodran Mustafi   4.00%        1877
# 9                 Alex Iwobi   1.00%        1812
# 10              Granit Xhaka   2.00%        1815
# 11   Alex Oxlade-Chamberlain   1.80%        1519
# 12             Jack Wilshere   0.00%        1759
# 13              Aaron Ramsey   5.10%        1040
# 14          Francis Coquelin   1.70%         549
# 15          Gabriel Paulista   0.10%         552
# 16              Kieran Gibbs   0.50%         489
# 17             Santi Cazorla   0.10%         943
# ...

# %%
popular_player=popular_player.sort_values('fpl_sel',ascending=False)
popular_player.head()
# Out:
#                name fpl_sel  page_views
# 241   Sergio Aguero   9.70%        4046
# 51    Asmir Begovic   9.30%         697
# 101         Willian   9.00%        1165
# 381  Jan Vertonghen   9.00%         511
# 245      Leroy Sane   8.80%        2302

# %%
df.market_value.mean()
# Out:
# 11.012039045553143

# %%
df.market_value.median()
# Out:
# 7.0

# %%
# the mean and the median are not close..(normal distrebution)

# %%
plot_for_value=df[['market_value']]
plot_for_value.plot.hist()

# %%
fantasy=df[['fpl_value','fpl_points']]
fantasy
# Out:
#      fpl_value  fpl_points
# 0         12.0         264
# 1          9.5         167
# 2          5.5         134
# 3          7.5         122
# 4          6.0         121
# 5          6.0         119
# 6          8.5         116
# 7          5.5         115
# 8          5.5          90
# 9          5.5          89
# 10         5.5          85
# 11         6.0          83
# 12         5.5          61
# 13         7.0          56
# 14         4.5          52
# 15         5.0          45
# 16         5.0          45
# 17         7.0          38
# 18         7.5          37
# 19         5.0          32
# 20         4.5          26
# 21         7.5          20
# 22         4.0           8
# 23         5.0           2
# 24         4.5           2
# 25         5.0           1
# 26         6.0           0
# 27        10.5           0
# 28         7.5         178
# 29         8.0         166
# ..         ...         ...
# 431        6.0          73
# 432        4.5          54
# ...

# %%
fantasy.mean()
# Out:
# fpl_value      5.447939
# fpl_points    57.314534
# dtype: float64

# %%
fantasy.median()
# Out:
# fpl_value      5.0
# fpl_points    51.0
# dtype: float64

# %%
fantasy.sort_values('fpl_value',ascending=False)
fantasy.head()
# Out:
#    fpl_value  fpl_points
# 0       12.0         264
# 1        9.5         167
# 2        5.5         134
# 3        7.5         122
# 4        6.0         121

# %%
sns.heatmap(fantasy.corr(),annot=True)

# %%
# caculate the correlation for market value and age
correlation=df['market_value'].corr(df['age'])
correlation
# Out:
# -0.13239623149378987

# %%
market_age=df[['market_value','age']]
market_age.plot.hist()

# %%
#extract the club and posotion_cat
stock=df[['club','position_cat']]
stock['club'].value_counts()
# Out:
# Arsenal              28
# Huddersfield         28
# Everton              28
# Liverpool            27
# Swansea              25
# Manchester+United    25
# Bournemouth          24
# Leicester+City       24
# Watford              24
# Southampton          23
# Stoke+City           22
# Brighton+and+Hove    22
# West+Ham             22
# Newcastle+United     21
# Crystal+Palace       21
# Manchester+City      20
# Tottenham            20
# Chelsea              20
# West+Brom            19
# Burnley              18
# Name: club, dtype: int64

# %%
attackers = valuable_players[valuable_players.position_cat==1]
attackers['club'].value_counts().head(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-219c50deb224> in <module>
# ----> 1 attackers = valuable_players[valuable_players.position_cat==1]
#       2 attackers['club'].value_counts().head(2)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'position_cat'

# %%
data.corr()
# Out:
#                    age  position_cat  market_value  page_views  fpl_value  \
# age           1.000000      0.220678     -0.132396   -0.048682  -0.097659
# position_cat  0.220678      1.000000     -0.217637   -0.279432  -0.491800
# market_value -0.132396     -0.217637      1.000000    0.739657   0.788653
# page_views   -0.048682     -0.279432      0.739657    1.000000   0.730640
# fpl_value    -0.097659     -0.491800      0.788653    0.730640   1.000000
# fpl_points    0.187785     -0.084682      0.615155    0.542464   0.618837
# region        0.086291     -0.062379      0.101636    0.031035   0.082414
# new_foreign  -0.125400      0.001415      0.098056   -0.049725   0.108650
# age_cat       0.972199      0.196853     -0.117682   -0.041672  -0.082056
# club_id      -0.002868     -0.016599     -0.046068   -0.092409  -0.060884
# big_club     -0.123566      0.017915      0.593483    0.502982   0.423556
# new_signing  -0.079190     -0.105127      0.131321    0.127249   0.098314
#
# ...

# %%
sns.heatmap(data.corr(), annot=True)

# %%
data[["age", "market_value"]].head()
# Out:
#    age  market_value
# 0   28          65.0
# 1   28          50.0
# 2   35           7.0
# 3   28          20.0
# 4   31          22.0

# %%
data[["age", "market_value"]].rank().head()
# Out:
#      age  market_value
# 0  296.0         458.0
# 1  296.0         453.5
# 2  450.5         239.5
# 3  296.0         385.5
# 4  391.5         393.5

# %%
data[["age", "market_value"]].rank().plot.scatter(x ="age", y="market_value")

# %%
data[["name", "position"]].rank().head()
# Out:
#     name  position
# 0   20.0     365.5
# 1  303.0       9.0
# 2  349.0     283.5
# 3  419.0     438.5
# 4  251.0      60.0

# %%
data[["name", "position"]].head()
# Out:
#                 name position
# 0     Alexis Sanchez       LW
# 1         Mesut Ozil       AM
# 2          Petr Cech       GK
# 3       Theo Walcott       RW
# 4  Laurent Koscielny       CB

# %%
data[["name", "position"]].rank().plot.scatter(x ="name", y="position")
